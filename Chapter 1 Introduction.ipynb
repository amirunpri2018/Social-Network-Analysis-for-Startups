# %%
import networkx as nx
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !ls SNABook/chapter1/
# Out:
# ACME_advice.net
# ACME_orgchart.net
# egypt_retweets.net
# generate_acme.py

# %%
orgchart = nx.read_pajek('SNABook/chapter1/ACME_orgchart.net')
nx.draw(orgchart)

# %%
advice = nx.read_pajek('SNABook/chapter1/ACME_advice.net')
nx.draw(advice)
